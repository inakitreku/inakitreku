# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
data = pd.read_csv('Raincloud_data.csv')

# %%
# !pip install ptitprince
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ptitprince
#   Downloading ptitprince-0.2.6-py3-none-any.whl (10 kB)
# Collecting PyHamcrest>=1.9.0
#   Downloading pyhamcrest-2.0.4-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.9/52.9 KB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from ptitprince) (1.8.0)
# Collecting cython
#   Downloading Cython-0.29.32-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting seaborn==0.11
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.1/283.1 KB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16 in /usr/lib/python3/dist-packages (from ptitprince) (1.21.5)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from ptitprince) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in /home/inakitreku/.local/lib/python3.10/site-packages (from seaborn==0.11->ptitprince) (1.4.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn==0.11->ptitprince) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn==0.11->ptitprince) (2022.1)
# Installing collected packages: PyHamcrest, cython, seaborn, ptitprince
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# Successfully installed PyHamcrest-2.0.4 cython-0.29.32 ptitprince-0.2.6 seaborn-0.11.0

# %%
from ptitprince import RainCloud
from ptitprince import PtitPrince as pt

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Pclass", y="Fare", data=train, capsize= .1)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
# plotting the clouds
f, ax = plt.subplots(figsize=(12,12))
dy="Pclass"
dx="Fare"
ort="h"
pal = sns.color_palette(n_colors=1)

ax=pt.half_violinplot(x=dx, y=dy, data=train, palette=pal, bw=.2, cut=0.,
                      scale="area", width=.6, inner=None, orient=ort)

# %%
# adding the rain
f, ax = plt.subplots(figsize=(12,12))
dy="Pclass"
dx="Fare"
ort="h"
pal = sns.color_palette(n_colors=1)

ax=pt.half_violinplot(x=dx, y=dy, data=train, palette=pal, bw=.2, cut=0.,
                      scale="area", width=.6, inner=None, orient=ort)
ax=sns.stripplot(x=dx, y=dy, data=train, palette=pal, edgecolor="white",
                 size=3, jitter=0, zorder=0, orient=ort)

# %%
# adding jitter to the rain
f, ax = plt.subplots(figsize=(12,12))
ax=pt.half_violinplot(x=dx, y=dy, data=train, palette=pal, bw=.2, cut=0.,
                      scale="area", width=.6, inner=None, orient=ort)
ax=sns.stripplot(x=dx, y=dy, data=train, palette=pal, edgecolor="white",
                 size=3, jitter=1, zorder=0, orient=ort)

# %%
#adding the boxplot with quartiles
f, ax = plt.subplots(figsize=(12,12))
ax=pt.half_violinplot(x=dx, y=dy, data=train, palette=pal, bw=.2, cut=0.,
                      scale="area", width=.6, inner=None, orient=ort)
ax=sns.stripplot(x=dx, y=dy, data=train, palette=pal, edgecolor="white",
                 size=3, jitter=1, zorder=0, orient=ort)
ax=sns.boxplot(x=dx, y=dy, data=train, color="black", width=.15, zorder=10,
               showcaps=True, boxprops={'facecolor': 'none', "zorder": 10},
               showfliers=True, whiskerprops={'linewidth': 2, "zorder": 10},
               saturation=1, orient=ort)
